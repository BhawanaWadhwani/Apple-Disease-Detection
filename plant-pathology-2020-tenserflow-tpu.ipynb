# %%
# !pip install knockknock #For sending message to telegram
# !pip install -q efficientnet
# Out:
# Collecting knockknock
#   Downloading knockknock-0.1.8.1-py3-none-any.whl (28 kB)
# Collecting python-telegram-bot
#   Downloading python_telegram_bot-12.7-py2.py3-none-any.whl (375 kB)
#      |████████████████████████████████| 375 kB 6.6 MB/s
# Collecting matrix-client
#   Downloading matrix_client-0.3.2-py2.py3-none-any.whl (28 kB)
# Collecting yagmail>=0.11.214
#   Downloading yagmail-0.11.224-py2.py3-none-any.whl (16 kB)
# Collecting twilio
#   Downloading twilio-6.40.0.tar.gz (426 kB)
#      |████████████████████████████████| 426 kB 10.5 MB/s
# Requirement already satisfied: keyring in /opt/conda/lib/python3.7/site-packages (from knockknock) (21.1.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from knockknock) (2.23.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.7/site-packages (from python-telegram-bot->knockknock) (2020.4.5.1)
# Collecting tornado>=5.1
#   Downloading tornado-6.0.4.tar.gz (496 kB)
#      |████████████████████████████████| 496 kB 16.9 MB/s
# Requirement already satisfied: future>=0.16.0 in /opt/conda/lib/python3.7/site-packages (from python-telegram-bot->knockknock) (0.18.2)
# Requirement already satisfied: cryptography in /opt/conda/lib/python3.7/site-packages (from python-telegram-bot->knockknock) (2.8)
# Requirement already satisfied: decorator>=4.4.0 in /opt/conda/lib/python3.7/site-packages (from python-telegram-bot->knockknock) (4.4.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from twilio->knockknock) (1.14.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.7/site-packages (from twilio->knockknock) (2019.3)
# Requirement already satisfied: PyJWT>=1.4.2 in /opt/conda/lib/python3.7/site-packages (from twilio->knockknock) (1.7.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from keyring->knockknock) (1.6.0)
# Requirement already satisfied: SecretStorage>=3; sys_platform == "linux" in /opt/conda/lib/python3.7/site-packages (from keyring->knockknock) (3.1.2)
# Requirement already satisfied: jeepney>=0.4.2; sys_platform == "linux" in /opt/conda/lib/python3.7/site-packages (from keyring->knockknock) (0.4.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->knockknock) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->knockknock) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->knockknock) (1.24.3)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /opt/conda/lib/python3.7/site-packages (from cryptography->python-telegram-bot->knockknock) (1.14.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->keyring->knockknock) (3.1.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi!=1.11.3,>=1.8->cryptography->python-telegram-bot->knockknock) (2.20)
# Building wheels for collected packages: twilio, tornado
# done
#   Created wheel for twilio: filename=twilio-6.40.0-py2.py3-none-any.whl size=1129362 sha256=b8b66542d14f6b571cb1b4e6cdceef22b617a772ab66153780052b19af346080
#   Stored in directory: /root/.cache/pip/wheels/41/d8/e2/128f5a3ca355dd485229721016fdb70ca14606eab260825701
# done
#   Created wheel for tornado: filename=tornado-6.0.4-cp37-cp37m-linux_x86_64.whl size=428630 sha256=7e2660ae278e3bf20243766e5e36992b31dcc43180c933a756a41e7b5192ba7e
#   Stored in directory: /root/.cache/pip/wheels/7d/14/fa/d88fb5da77d813ea0ffca38a2ab2a052874e9e1142bad0b348
# Successfully built twilio tornado
# ERROR: jupyterlab-git 0.10.0 has requirement nbdime<2.0.0,>=1.1.0, but you'll have nbdime 2.0.0 which is incompatible.
# Installing collected packages: tornado, python-telegram-bot, matrix-client, yagmail, twilio, knockknock
#   Attempting uninstall: tornado
#     Found existing installation: tornado 5.0.2
#     Uninstalling tornado-5.0.2:
#       Successfully uninstalled tornado-5.0.2
# Successfully installed knockknock-0.1.8.1 matrix-client-0.3.2 python-telegram-bot-12.7 tornado-6.0.4 twilio-6.40.0 yagmail-0.11.224
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
import os
import cv2
import math
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
from sklearn.metrics import confusion_matrix,accuracy_score,roc_auc_score,precision_score,recall_score,ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split,KFold,StratifiedKFold
from transformers import get_cosine_schedule_with_warmup
from albumentations import *
from kaggle_datasets import KaggleDatasets

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras import optimizers
import efficientnet.tfkeras as efn
from albumentations import *


from knockknock import telegram_sender 
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
token = user_secrets.get_secret("token")
chat_id = user_secrets.get_secret("chat_id")

import warnings  
warnings.filterwarnings('ignore')

# %%
AUTO = tf.data.experimental.AUTOTUNE

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy()
    
print("REPLICAS: ", strategy.num_replicas_in_sync)

GCS_DS_PATH = KaggleDatasets().get_gcs_path()
# Out:
# Running on TPU  grpc://10.0.0.2:8470
# REPLICAS:  8

# %%
SEED = 42
BATCH_SIZE = 8 * strategy.num_replicas_in_sync
SIZE = [800,800]
LR = 0.0008
WEIGHT_DECAY = 0
EPOCHS = 40
WARMUP = 15
TTA = 4

# %%
def seed_everything(SEED):
    np.random.seed(SEED)
    tf.random.set_seed(SEED)

seed_everything(SEED)

# %%
DIR_INPUT = '/kaggle/input/plant-pathology-2020-fgvc7'
train_df = pd.read_csv(DIR_INPUT + '/train.csv')
test_df = pd.read_csv(DIR_INPUT + '/test.csv')
cols = list(train_df.columns[1:])

# %%
train,valid = train_test_split(train_df,test_size = 0.2,random_state = SEED)

# %%
transform = {
    'train' :Compose([
        Resize(SIZE[0],SIZE[1],always_apply=True),
        HorizontalFlip(p=0.5),
        VerticalFlip(p=0.5),
        RandomRotate90(p=0.5),
        Rotate(limit=25.0,p=0.8)]) }

def preprocess(df,test=False):
    paths = df.image_id.apply(lambda x: GCS_DS_PATH + '/images/' + x + '.jpg').values
    labels = df.loc[:,'healthy':].values
    if test==False:
        return paths,labels
    else:
        return paths
    
def decode_image(filename, label=None, image_size=(SIZE[0], SIZE[1])):
    bits = tf.io.read_file(filename)
    image = tf.image.decode_jpeg(bits, channels=3) 
    image = tf.image.resize(image, image_size)
    image = tf.cast(image, tf.float32)
    image = tf.image.per_image_standardization(image)
    if label is None:
        return image
    else:
        return image, label
    
def data_augment(image, label=None, seed=SEED):
    image = tf.image.rot90(image,k=np.random.randint(4))
    image = tf.image.random_flip_left_right(image, seed=seed)
    image = tf.image.random_flip_up_down(image, seed=seed)
    if label is None:
        return image
    else:
        return image, label
    
def albu(image):
    transforms = transform['train']
    image = transforms(image=image.numpy())['image']
    image = tf.cast(image, tf.float32)
    return image
    
def albu_fn(image,label=None):
    [image,] = tf.py_function(albu, [image], [tf.float32])
    if label is None:
        return image
    else:
        return image, label

# %%
train_dataset = (tf.data.Dataset
    .from_tensor_slices(preprocess(train))
    .map(decode_image, num_parallel_calls=AUTO)
    .map(data_augment, num_parallel_calls=AUTO)
    .shuffle(SEED)
    .batch(BATCH_SIZE,drop_remainder=True)
    .repeat()
    .prefetch(AUTO))

valid_dataset = (tf.data.Dataset
    .from_tensor_slices(preprocess(valid))
    .map(decode_image, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE)
    .cache()
    .prefetch(AUTO))

test_dataset = (tf.data.Dataset
    .from_tensor_slices(preprocess(test_df,test=True))
    .map(decode_image, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE))

# %%
def plot_transform(image_id,num_images=7):
    plt.figure(figsize=(30,10))
    path,_ = preprocess(train.iloc[image_id:image_id+1])
    for i in range(1,num_images+1):
        plt.subplot(1,num_images+1,i)
        plt.axis('off')
        image = decode_image(filename=path[0])
        image = data_augment(image=image)
        plt.imshow(image)

plot_transform(9)

# %%
with strategy.scope():
    model = tf.keras.Sequential([
        efn.EfficientNetB7(input_shape=(SIZE[0], SIZE[1], 3),weights='imagenet',pooling='avg',include_top=False),
        Dense(4, activation='softmax')
    ])
        
    model.compile(
        optimizer='adam',
        loss = 'categorical_crossentropy',
        metrics=['categorical_accuracy'])
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b7_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 258441216/258434480 [==============================] - 3s 0us/step

# %%
def get_cosine_schedule_with_warmup(lr,num_warmup_steps, num_training_steps, num_cycles=0.5):
    """
    Modified the get_cosine_schedule_with_warmup from huggingface for tenserflow
    (https://huggingface.co/transformers/_modules/transformers/optimization.html#get_cosine_schedule_with_warmup)

    Create a schedule with a learning rate that decreases following the
    values of the cosine function between 0 and `pi * cycles` after a warmup
    period during which it increases linearly between 0 and 1.
    """

    def lrfn(epoch):
        if epoch < num_warmup_steps:
            return float(epoch) / float(max(1, num_warmup_steps)) * lr
        progress = float(epoch - num_warmup_steps) / float(max(1, num_training_steps - num_warmup_steps))
        return max(0.0, 0.5 * (1.0 + math.cos(math.pi * float(num_cycles) * 2.0 * progress))) * lr

    return tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

lr_schedule= get_cosine_schedule_with_warmup(lr=LR,num_warmup_steps=WARMUP,num_training_steps=EPOCHS)

# %%
STEPS_PER_EPOCH = train.shape[0] // BATCH_SIZE
@telegram_sender(token=token, chat_id=int(chat_id))
def train():
    history = model.fit(
        train_dataset, 
        epochs=EPOCHS, 
        callbacks=[lr_schedule],
        steps_per_epoch=STEPS_PER_EPOCH,
        validation_data=valid_dataset)
    
    string = 'Train acc:{:.4f} Train loss:{:.4f},Val acc:{:.4f} Val loss:{:.4f}'.format( \
        model.history.history['categorical_accuracy'][-1],model.history.history['loss'][-1],\
        model.history.history['val_categorical_accuracy'][-1],model.history.history['val_loss'][-1])
    
    return string

# %%
train()
# Out:
# Train for 22 steps, validate for 6 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0.
# Epoch 1/40
# 22/22 [==============================] - 359s 16s/step - loss: 1.3807 - categorical_accuracy: 0.2869 - val_loss: 1.3894 - val_categorical_accuracy: 0.2603
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 5.333333333333333e-05.
# Epoch 2/40
# 22/22 [==============================] - 26s 1s/step - loss: 1.1947 - categorical_accuracy: 0.6143 - val_loss: 1.0588 - val_categorical_accuracy: 0.7068
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.00010666666666666667.
# Epoch 3/40
# 22/22 [==============================] - 26s 1s/step - loss: 0.5706 - categorical_accuracy: 0.8338 - val_loss: 0.7688 - val_categorical_accuracy: 0.7808
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00016.
# Epoch 4/40
# 22/22 [==============================] - 26s 1s/step - loss: 0.3461 - categorical_accuracy: 0.8864 - val_loss: 0.3488 - val_categorical_accuracy: 0.9041
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.00021333333333333333.
# Epoch 5/40
# 22/22 [==============================] - 26s 1s/step - loss: 0.2698 - categorical_accuracy: 0.9112 - val_loss: 0.3418 - val_categorical_accuracy: 0.9014
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0002666666666666667.
# Epoch 6/40
# 22/22 [==============================] - 26s 1s/step - loss: 0.1809 - categorical_accuracy: 0.9396 - val_loss: 0.2398 - val_categorical_accuracy: 0.9507
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.00032.
# Epoch 7/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.2107 - categorical_accuracy: 0.9318 - val_loss: 0.2709 - val_categorical_accuracy: 0.9288
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0003733333333333334.
# Epoch 8/40
# 22/22 [==============================] - 28s 1s/step - loss: 0.1788 - categorical_accuracy: 0.9425 - val_loss: 0.1513 - val_categorical_accuracy: 0.9616
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.00042666666666666667.
# Epoch 9/40
# 22/22 [==============================] - 28s 1s/step - loss: 0.1783 - categorical_accuracy: 0.9432 - val_loss: 0.2803 - val_categorical_accuracy: 0.9233
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.00048.
# Epoch 10/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.1803 - categorical_accuracy: 0.9432 - val_loss: 0.3729 - val_categorical_accuracy: 0.9151
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0005333333333333334.
# Epoch 11/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.1739 - categorical_accuracy: 0.9510 - val_loss: 0.5088 - val_categorical_accuracy: 0.8000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0005866666666666667.
# Epoch 12/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.1451 - categorical_accuracy: 0.9517 - val_loss: 0.2509 - val_categorical_accuracy: 0.9507
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.00064.
# Epoch 13/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.1075 - categorical_accuracy: 0.9659 - val_loss: 0.6041 - val_categorical_accuracy: 0.9233
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0006933333333333333.
# Epoch 14/40
# 22/22 [==============================] - 28s 1s/step - loss: 0.1381 - categorical_accuracy: 0.9567 - val_loss: 0.4753 - val_categorical_accuracy: 0.9260
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0007466666666666667.
# Epoch 15/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.1000 - categorical_accuracy: 0.9659 - val_loss: 0.5034 - val_categorical_accuracy: 0.9068
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0008.
# Epoch 16/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.1214 - categorical_accuracy: 0.9602 - val_loss: 0.3261 - val_categorical_accuracy: 0.9452
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0007968458805257912.
# Epoch 17/40
# 22/22 [==============================] - 26s 1s/step - loss: 0.0994 - categorical_accuracy: 0.9723 - val_loss: 0.3759 - val_categorical_accuracy: 0.9425
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0007874332644514524.
# Epoch 18/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.0957 - categorical_accuracy: 0.9652 - val_loss: 0.4841 - val_categorical_accuracy: 0.9123
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0007719105943553005.
# Epoch 19/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.1116 - categorical_accuracy: 0.9673 - val_loss: 0.2984 - val_categorical_accuracy: 0.9123
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0007505226720175454.
# Epoch 20/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.0998 - categorical_accuracy: 0.9744 - val_loss: 0.4803 - val_categorical_accuracy: 0.9205
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.000723606797749979.
# Epoch 21/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.0742 - categorical_accuracy: 0.9780 - val_loss: 0.2241 - val_categorical_accuracy: 0.9534
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0006915874509685647.
# Epoch 22/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.0233 - categorical_accuracy: 0.9950 - val_loss: 0.2942 - val_categorical_accuracy: 0.9562
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.000654969595899476.
# Epoch 23/40
# 22/22 [==============================] - 26s 1s/step - loss: 0.0331 - categorical_accuracy: 0.9872 - val_loss: 0.2123 - val_categorical_accuracy: 0.9534
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0006143307179915986.
# Epoch 24/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.0400 - categorical_accuracy: 0.9901 - val_loss: 0.2582 - val_categorical_accuracy: 0.9534
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0005703117166260291.
# Epoch 25/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.0433 - categorical_accuracy: 0.9872 - val_loss: 0.1491 - val_categorical_accuracy: 0.9562
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0005236067977499791.
# Epoch 26/40
# 22/22 [==============================] - 26s 1s/step - loss: 0.0207 - categorical_accuracy: 0.9950 - val_loss: 0.1382 - val_categorical_accuracy: 0.9644
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00047495252583428996.
# Epoch 27/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.0300 - categorical_accuracy: 0.9922 - val_loss: 0.2002 - val_categorical_accuracy: 0.9616
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0004251162078117254.
# Epoch 28/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.0124 - categorical_accuracy: 0.9964 - val_loss: 0.1415 - val_categorical_accuracy: 0.9644
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0003748837921882747.
# Epoch 29/40
# 22/22 [==============================] - 26s 1s/step - loss: 0.0077 - categorical_accuracy: 0.9979 - val_loss: 0.1625 - val_categorical_accuracy: 0.9699
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0003250474741657101.
# Epoch 30/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.0048 - categorical_accuracy: 0.9993 - val_loss: 0.1706 - val_categorical_accuracy: 0.9671
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0002763932022500211.
# Epoch 31/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.0037 - categorical_accuracy: 0.9993 - val_loss: 0.1710 - val_categorical_accuracy: 0.9671
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.00022968828337397094.
# Epoch 32/40
# 22/22 [==============================] - 26s 1s/step - loss: 0.0084 - categorical_accuracy: 0.9986 - val_loss: 0.1660 - val_categorical_accuracy: 0.9671
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.00018566928200840126.
# Epoch 33/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.0093 - categorical_accuracy: 0.9964 - val_loss: 0.1484 - val_categorical_accuracy: 0.9699
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001450304041005241.
# Epoch 34/40
# 22/22 [==============================] - 26s 1s/step - loss: 0.0070 - categorical_accuracy: 0.9979 - val_loss: 0.1473 - val_categorical_accuracy: 0.9699
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.00010841254903143547.
# Epoch 35/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.0050 - categorical_accuracy: 0.9993 - val_loss: 0.1412 - val_categorical_accuracy: 0.9726
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 7.639320225002106e-05.
# Epoch 36/40
# 22/22 [==============================] - 26s 1s/step - loss: 0.0025 - categorical_accuracy: 0.9993 - val_loss: 0.1419 - val_categorical_accuracy: 0.9699
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 4.947732798245466e-05.
# Epoch 37/40
# 22/22 [==============================] - 27s 1s/step - loss: 0.0044 - categorical_accuracy: 0.9979 - val_loss: 0.1395 - val_categorical_accuracy: 0.9671
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 2.8089405644699463e-05.
# Epoch 38/40
# 22/22 [==============================] - 26s 1s/step - loss: 0.0044 - categorical_accuracy: 0.9993 - val_loss: 0.1414 - val_categorical_accuracy: 0.9671
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 1.256673554854757e-05.
# Epoch 39/40
# 22/22 [==============================] - 26s 1s/step - loss: 0.0069 - categorical_accuracy: 0.9993 - val_loss: 0.1414 - val_categorical_accuracy: 0.9671
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 3.154119474208894e-06.
# Epoch 40/40
# 22/22 [==============================] - 26s 1s/step - loss: 0.0054 - categorical_accuracy: 0.9993 - val_loss: 0.1419 - val_categorical_accuracy: 0.9671
# 'Train acc:0.9993 Train loss:0.0054,Val acc:0.9671 Val loss:0.1419'

# %%
def display_training_curves(training, validation, title, subplot):
    """
    Source: https://www.kaggle.com/mgornergoogle/getting-started-with-100-flowers-on-tpu
    """
    if subplot%10==1: # set up the subplots on the first call
        plt.subplots(figsize=(15,15), facecolor='#F0F0F0')
        plt.tight_layout()
    ax = plt.subplot(subplot)
    ax.set_facecolor('#F8F8F8')
    ax.plot(training)
    ax.plot(validation)
    ax.set_title('model '+ title)
    ax.set_ylabel(title)
    ax.set_xlabel('epoch')
    ax.legend(['train', 'valid.'])

# %%
display_training_curves(
    model.history.history['loss'], 
    model.history.history['val_loss'], 
    'loss', 211)
display_training_curves(
    model.history.history['categorical_accuracy'], 
    model.history.history['val_categorical_accuracy'], 
    'accuracy', 212)

# %%
test_pred = model.predict(test_dataset, verbose=1)
submission_df = pd.read_csv(DIR_INPUT + '/sample_submission.csv')
submission_df[['healthy', 'multiple_diseases', 'rust', 'scab']] = test_pred
submission_df.to_csv('submission.csv', index=False)
pd.Series(np.argmax(submission_df[cols].values,axis=1)).value_counts()
# Out:
# 29/29 [==============================] - 122s 4s/step
# 2    768
# 3    601
# 0    367
# 1     85
# dtype: int64

# %%
test_pred_tta = np.zeros((len(test_df),4))
for i in range(TTA):
    test_dataset_tta = (tf.data.Dataset
    .from_tensor_slices(preprocess(test_df,test=True))
    .map(decode_image, num_parallel_calls=AUTO)
    .map(data_augment, num_parallel_calls=AUTO)    
    .batch(BATCH_SIZE))
    test_pred_tta += model.predict(test_dataset_tta, verbose=1)
submission_df = pd.read_csv(DIR_INPUT + '/sample_submission.csv')
submission_df[['healthy', 'multiple_diseases', 'rust', 'scab']] = test_pred_tta/TTA
submission_df.to_csv('submission_tta.csv', index=False)
pd.Series(np.argmax(submission_df[cols].values,axis=1)).value_counts()
# Out:
# 29/29 [==============================] - 46s 2s/step
# 29/29 [==============================] - 47s 2s/step
# 29/29 [==============================] - 47s 2s/step
# 29/29 [==============================] - 49s 2s/step
# 2    770
# 3    608
# 0    366
# 1     77
# dtype: int64
